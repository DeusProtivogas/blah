# %%
import requests

# %%
requests.get('https://www.reddit.com') # 401 Unauthorized
# Out:
# <Response [401]>

# %%
requests.get('http://habrahabr.ru')
# Out:
# <Response [200]>

# %%
req = requests.get('http://habrahabr.ru')
req.
# Out:
#   File "<ipython-input-5-402120594812>", line 2
#     req.
#         ^
# SyntaxError: invalid syntax

# %%
from bs4 import BeautifulSoup # https://www.crummy.com/software/BeautifulSoup/bs4/doc/

# %%
page = requests.get('http://habrahabr.ru')
soup = BeautifulSoup(page.content, 'html.parser')

# %%
soup.find_all('div')
# Out:
# [<div class="layout">
#  <div class="layout__row layout__row_services">
#  <div id="TMpanel">
#  <div class="container">
#  <div class="bmenu">
#  <a class="current" href="https://habr.com?utm_source=tm_habrahabr&amp;utm_medium=tm_top_panel&amp;utm_campaign=tm_promo">Хабр</a>
#  <a href="https://habr.com/flows/geektimes/">Geektimes</a>
#  <a href="https://toster.ru?utm_source=tm_habrahabr&amp;utm_medium=tm_top_panel&amp;utm_campaign=tm_promo">Тостер</a>
#  <a href="https://moikrug.ru?utm_source=tm_habrahabr&amp;utm_medium=tm_top_panel&amp;utm_campaign=tm_promo">Мой круг</a>
#  <a href="https://freelansim.ru?utm_source=tm_habrahabr&amp;utm_medium=tm_top_panel&amp;utm_campaign=tm_promo">Фрилансим</a>
#  </div>
#  <div class="bmenu_inner" style="display:inline-block!important;visibility:visible!important;">
#  <span class="bmenu__label">Мегапосты:</span>
#  <span class="bmenu slink">
# ...

# %%
soup.find_all('h2')

# %%
soup.find_all('h2',{'class','post__title'})

# %%
for title in soup.find_all('h2',{'class','post__title'}):
    print(title.text.strip())

# %%
requests.get('https://pikabu.ru/')

# %%
headers = {'User-Agent': 'Mozilla/5.0 \
           (Macintosh; Intel Mac OS X 10_10_1) \
           AppleWebKit/537.36 (KHTML, like Gecko) \
           Chrome/39.0.2171.95 Safari/537.36'}

# %%
requests.get('https://pikabu.ru/',headers=headers)
# Out:
# <Response [200]>

# %%
TAGS = ['юмор','россия','боль','осень','яндекс'] # put here your own tags

# %%
#URL ='https://pikabu.ru/search?t={}%2CТекст&n=2&r=7&page=1'
URL ='https://pikabu.ru/tag/{}?n=2&r=6'

# %% [markdown]
# # Task 0
# Describe, why do we use ?t={}%2CТекст&n=2&r=7 in the cell above?
# * ? --
# * t={} --
# * %2CТекст --
# * &
# * n=2
# * r=7

# %%
page = requests.get(URL.format('Юмор'), headers=headers)

# %%
soup = BeautifulSoup(page.content, 'html.parser')

# %%
for i in soup.find_all('div',{'class':'story__content'})[:5]:
    print(i.text.strip(),end='\n\n')
# Out:
# UPD. К посту есть альтернативное мнение #comment_151644860Мы им так верили и приводили их в пример, но, оказывается, муравьи все это время нас обманывали. Они такие же лентяи, как и мы.
#
#
#
#
#
#
#
#
# ...

# %%
content = []
for i in soup.find_all('div', {'class':'story__content'}):
    content.append(i.text.strip())
print(len(content))
# Out:
# 16

# %%
content1 = []
for i in soup.find_all('a', {'class':'story__title-link'}):
    print(i['href'])
    #content.append(i.text.strip())
#print(len(content))
# Out:
# https://pikabu.ru/story/okazyivaetsya_muravi_vovse_ne_lyubyat_rabotat_vyiyasnili_uchenyie_6979458
# https://pikabu.ru/story/pochtovaya_rabotnitsa_6979097
# https://pikabu.ru/story/reniy__obrazets_samodostatochnosti_6978839
# https://pikabu.ru/story/sova__yeffektivnyiy_menedzher_sezon_4_6_yeffektivnoe_myishlenie_6978155
# https://pikabu.ru/story/kogda_devushka_khudeet_i_brosaet_kurit_odnovremenno_6978101
# https://pikabu.ru/story/borshch_6977961
# https://pikabu.ru/story/skala_6977812
# https://pikabu.ru/story/gera_doter_i_taynyi_sharagvartsa_4_6977493
# https://pikabu.ru/story/motivatsii_post_6977423
# https://pikabu.ru/story/drama_na_stackoverflow_6977123
# https://pikabu.ru/story/takuyu_knigu_ya_byi_pochital_6976356
# https://pikabu.ru/story/utinaya_blagotvoritelnost_2_62_6976309
# https://pikabu.ru/story/nichego_novogo_6975792
# https://pikabu.ru/story/a_chto_posle_30ti_nelzya_shutit_i_balovatsya_6975679
# https://pikabu.ru/story/afrikanets_6975382
# ...

# %%
content1 = []
for i in soup.find_all('a', {'class':'story__title-link'}):
    print(i['href'])
    url = i['href']
    page = requests.get(url, headers=headers)
    #print(page.content)
    soup = BeautifulSoup(page.content, 'html.parser')
# Out:
# https://pikabu.ru/story/okazyivaetsya_muravi_vovse_ne_lyubyat_rabotat_vyiyasnili_uchenyie_6979458
# https://pikabu.ru/story/pochtovaya_rabotnitsa_6979097
# https://pikabu.ru/story/reniy__obrazets_samodostatochnosti_6978839
# https://pikabu.ru/story/sova__yeffektivnyiy_menedzher_sezon_4_6_yeffektivnoe_myishlenie_6978155
# https://pikabu.ru/story/kogda_devushka_khudeet_i_brosaet_kurit_odnovremenno_6978101
# https://pikabu.ru/story/borshch_6977961
# https://pikabu.ru/story/skala_6977812
# https://pikabu.ru/story/gera_doter_i_taynyi_sharagvartsa_4_6977493
# https://pikabu.ru/story/motivatsii_post_6977423
# https://pikabu.ru/story/drama_na_stackoverflow_6977123
# https://pikabu.ru/story/takuyu_knigu_ya_byi_pochital_6976356
# https://pikabu.ru/story/utinaya_blagotvoritelnost_2_62_6976309
# https://pikabu.ru/story/nichego_novogo_6975792
# https://pikabu.ru/story/a_chto_posle_30ti_nelzya_shutit_i_balovatsya_6975679
# https://pikabu.ru/story/afrikanets_6975382
# ...

# %%
page = requests.get('https://pikabu.ru/story/okazyivaetsya_muravi_vovse_ne_lyubyat_rabotat_vyiyasnili_uchenyie_6979458', headers=headers)
soup = BeautifulSoup(page.content, 'html.parser')
# for i in soup.find_all('div', {'class': 'story-block story-block_type_text'}):
#     print(i.text.strip())
print(soup.find('div', {'class': 'story-block'}).text)
# Out:
# UPD. К посту есть альтернативное мнение #comment_151644860Мы им так верили и приводили их в пример, но, оказывается, муравьи все это время нас обманывали. Они такие же лентяи, как и мы.

# %%
content_list = []
for i in soup.find_all('div', {'class':'story__content'}):
    content_list.append(i.text.strip())

# %%
ll = list(map(str.lower, content_list))

# %%
[i.split() for i in ll]
    #print(i)
# Out:
# [['upd.',
#   'к',
#   'посту',
#   'есть',
#   'альтернативное',
#   'мнение',
#   '#comment_151644860мы',
#   'им',
#   'так',
#   'верили',
#   'и',
#   'приводили',
#   'их',
#   'в',
#   'пример,',
#   'но,',
#   'оказывается,',
#   'муравьи',
#   'все',
#   'это',
#   'время',
#   'нас',
#   'обманывали.',
#   'они',
#   'такие',
#   'же',
#   'лентяи,',
#   'как',
#   'и',
#   'мы.',
#   'по-видимому,',
#   'это',
#   'самое',
#   'шокирующее',
#   'изменение',
#   'картины',
#   'мира',
#   'со',
#   'времен',
#   'падения',
#   'цен',
#   'на',
#   'московскую',
#   'недвижимость.',
#   'или',
#   'даже',
#   'со',
#   'времен',
#   'внезапной',
#   'правды',
#   'про',
#   'деда',
#   'мороза,',
#   'ведь',
#   'об',
#   'аномальном',
#   'трудолюбии',
#   'муравьев',
#   'мы',
#   'тоже',
#   'знали',
#   'с',
#   'детства.',
#   'благо',
#   'это',
#   'качество',
#   'отрекламировал',
#   'еще',
#   'баснописец',
#   'крылов,',
#   'а',
#   'после',
#   'него',
#   '—',
# ...

# %%
dict1 = sum([i.split() for i in ll], [])

# %%
set(dict1)
# Out:
# {'муравейник',
#  'комната',
#  'знал).',
#  'бесплатные',
#  'аномальном',
#  'теперь',
#  'кофе,',
#  'посту',
#  'ванной.',
#  'все-таки',
#  'будущего',
#  'оформления',
#  'открывается',
#  '(ни',
#  'мой',
#  'будет',
#  'сам',
#  'гера',
#  'согласитесь,',
#  'некоторых',
#  'раздельный,',
#  'ощущения,',
#  'тоном',
#  'очереди',
#  'дальше',
#  'менеджер"©за',
#  'тишайшее',
#  'благо',
#  'часть',
#  'себе.нормальная',
#  'идеи',
#  'них',
#  'глазами',
#  'местоимений.автор',
#  '#3гера',
#  'найденного',
#  'могут',
#  'замеры.',
#  'дизайн-проект,',
#  'той,',
#  'комментарии',
#  'мороза,',
#  'населения)',
#  'всех',
#  'пор',
#  'неизвестность',
#  'нечего',
#  'вами',
#  'имела',
#  'прочее',
#  'рабочих.',
#  'избавились:',
#  'части.',
#  'перегородок',
#  'дeло',
#  'половины',
#  'нельзя',
#  'план',
#  'шокирующее',
#  'представленные',
#  'спец',
#  'евроформата',
#  'вашем',
#  'кв.',
#  'самое',
#  'было',
#  'платить',
#  'ванной',
#  'офигели.и',
# ...

# %% [markdown]
# # Task 1
# Fetch non-blank 100 posts for each TAGS

# %% [markdown]
# # Bag of words

# %% [markdown]
# <img src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSDULOITIaIm8GF0pBBmBVMHkPUFf_X3cNK9z274pYxORhMqu7z">
#
# https://www.oreilly.com/library/view/feature-engineering-for/9781491953235/ch04.html

# %% [markdown]
# # Task 2
# Build dictionary of the corpus

# %% [markdown]
# # Task 3
# Build BoW matrix for the corpus

# %% [markdown]
# # Task 4
# Find the closest posts in corpus and print 5 representatives of each Tag.
#
# Which metric has been used?
