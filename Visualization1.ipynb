# %% [markdown]
# # Matplotlib
# https://matplotlib.org/index.html
#
# Installing:
# * python -m pip install -U pip
# * python -m pip install -U matplotlib

# %%
import matplotlib.pyplot as plt
plt.plot([1, 2, 3, 4,2]) # line plot
plt.ylabel('some numbers')
plt.show()

# %%
# ?plt.plot

# %%
# %matplotlib inline

# %%
plt.plot([1, 2, 3] ,[4,2,1])
plt.axis([0, 3, 0, 4])
# Out:
# [0, 3, 0, 4]

# %%
import pandas as pd

# %%
data = pd.read_csv('train.csv') # from titanic

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
plt.plot(data.Age,data.Fare,'s-')

# %%
plt.scatter(data.Age,data.Fare,s=data.Pclass*10,c=data.Pclass) # scatter plot

# %%
plt.scatter(data.Sex.value_counts().index,data.Sex.value_counts().values, s=data.Pclass*10,c=data.Pclass) # scatter plot
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-33-542dd8c44a4a> in <module>()
# ----> 1 plt.scatter(data.Sex,data.Sex,s=data.Pcalss*10) # scatter plot
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    3612             if name in self._info_axis:
#    3613                 return self[name]
# -> 3614             return object.__getattribute__(self, name)
#    3615
#    3616     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'Pcalss'

# %%
plt.bar(data.Sex.value_counts().index,data.Sex.value_counts().values) # categorical
# Out:
# <Container object of 2 artists>

# %%
plt.hist(data.Age.dropna(),bins=10) # number range
# Out:
# (array([ 54.,  46., 177., 169., 118.,  70.,  45.,  24.,   9.,   2.]),
#  array([ 0.42 ,  8.378, 16.336, 24.294, 32.252, 40.21 , 48.168, 56.126,
#         64.084, 72.042, 80.   ]),
#  <a list of 10 Patch objects>)

# %%
#plt.figure()
plt.subplot(333)
plt.plot(data.Age,data.Fare, 'bo', 'k')

plt.subplot(337)
plt.plot(data.Age,data.Fare, 'r--')

# %% [markdown]
# ### more examples
# https://matplotlib.org/3.1.1/tutorials/introductory/sample_plots.html

# %% [markdown]
# # Plotly
# https://plot.ly/python/getting-started/

# %%
import plotly.graph_objs as go
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
init_notebook_mode(connected=True)
iplot([{"x": [1, 2, 3], "y": [3, 1, 6]}])
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-45-49d826a5d461> in <module>()
# ----> 1 import plotly.graph_objs as go
#       2 from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
#       3 init_notebook_mode(connected=True)
#       4 iplot([{"x": [1, 2, 3], "y": [3, 1, 6]}])
#
# ModuleNotFoundError: No module named 'plotly'

# %%
import plotly.graph_objs as go

labels = ['Oxygen','Hydrogen','Carbon_Dioxide','Nitrogen']
values = [4500, 2500, 1053, 500]

iplot(go.Figure(data=[go.Pie(labels=labels, values=values)]))
# Out:
# <div id="acf537fe-a2da-44d0-a32e-1c2c30b7dcbb" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("acf537fe-a2da-44d0-a32e-1c2c30b7dcbb", [{"labels": ["Oxygen", "Hydrogen", "Carbon_Dioxide", "Nitrogen"], "values": [4500, 2500, 1053, 500], "type": "pie", "uid": "8a088ca5-a836-4416-87da-2c369000e4bc"}], {}, {"showLink": true, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly"})});</script><script type="text/javascript">window.addEventListener("resize", function(){window._Plotly.Plots.resize(document.getElementById("acf537fe-a2da-44d0-a32e-1c2c30b7dcbb"));});</script>

# %% [markdown]
# # Tasks:

# %% [markdown]
# Using titanic data:
# * bar char for Embarked
# * men and women survided or not pie chart (4 type)
# * fare hist
# * 2 subplots: age range(0,5,10,15,...) and mean fate line plot
# * miss, mrs, ms -- horizontal bar charts

# %%
plt.bar(data.Embarked.value_counts().index,data.Embarked.value_counts().values)
# Out:
# <Container object of 3 artists>

# %%
tar = data[['Survived', 'Sex']]
X = ('men died', 'men survived', 'women died', 'women survived')

# %%
Y = list(tar[tar.Sex=='male'].Survived.value_counts().values) + list(tar[tar.Sex=='female'].Survived.value_counts().values)
Y
# Out:
# [468, 109, 233, 81]

# %%
plt.pie(Y, labels=X, radius=2)
# Out:
# ([<matplotlib.patches.Wedge at 0x29c7568c908>,
# ...
#  [Text(-0.17435,2.19308,'men died'),
#   Text(-1.88357,-1.13674,'men survived'),
#   Text(0.389663,-2.16522,'women died'),
#   Text(2.11088,-0.619812,'women survived')])

# %%
plt.hist(data.Fare, bins=4)
# Out:
# (array([853.,  29.,   6.,   3.]),
#  array([  0.    , 128.0823, 256.1646, 384.2469, 512.3292]),
#  <a list of 4 Patch objects>)

# %%
plt.figure()
plt.subplot()
plt.plot(data.Age, [0, 5])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-111-7c885d300a21> in <module>()
#       1 plt.figure()
#       2 plt.subplot()
# ----> 3 plt.plot(data.Age, [0, 5])
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\pyplot.py in plot(*args, **kwargs)
#    3259                       mplDeprecation)
#    3260     try:
# -> 3261         ret = ax.plot(*args, **kwargs)
#    3262     finally:
#    3263         ax._hold = washold
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, *args, **kwargs)
#    1715                     warnings.warn(msg % (label_namer, func.__name__),
#    1716                                   RuntimeWarning, stacklevel=2)
# -> 1717             return func(ax, *args, **kwargs)
#    1718         pre_doc = inner.__doc__
#    1719         if pre_doc is None:
#
# ...

# %%
plt.pie(tar[tar.Sex=='male'].Survived.value_counts(), labels=('Died', 'Survived'))
# Out:
# ([<matplotlib.patches.Wedge at 0x29c739ab828>,
# ...
#  [Text(-0.911904,0.615167,'Died'), Text(0.911904,-0.615167,'Survived')])

# %%
plt.pie(tar[tar.Sex=='female'].Survived.value_counts(), labels=('Died', 'Survived'))
# Out:
# ([<matplotlib.patches.Wedge at 0x29c739ec898>,
# ...
#  [Text(-0.758121,0.797027,'Died'), Text(0.758121,-0.797028,'Survived')])

# %%
plt.pie(data.Sex=='male')
# Out:
# ([<matplotlib.patches.Wedge at 0x29c7135ab38>,
# ...
#  [Text(1.09998,0.00598914,''),
#   Text(1.09993,0.0119781,''),
#   Text(1.09993,0.0119781,''),
#   Text(1.09993,0.0119781,''),
#   Text(1.09985,0.0179667,''),
#   Text(1.09959,0.0299422,''),
#   Text(1.0992,0.0419141,''),
#   Text(1.09868,0.053881,''),
#   Text(1.09837,0.0598621,''),
#   Text(1.09837,0.0598621,''),
#   Text(1.09837,0.0598621,''),
#   Text(1.09837,0.0598621,''),
#   Text(1.09803,0.0658415,''),
#   Text(1.09725,0.0777942,''),
#   Text(1.09681,0.0837672,''),
#   Text(1.09681,0.0837672,''),
#   Text(1.09633,0.0897377,''),
#   Text(1.09529,0.101671,''),
#   Text(1.09472,0.107633,''),
#   Text(1.09472,0.107633,''),
#   Text(1.09412,0.113591,''),
#   Text(1.09282,0.125499,''),
#   Text(1.09212,0.131447,''),
#   Text(1.09139,0.137391,''),
#   Text(1.09062,0.143331,''),
#   Text(1.09062,0.143331,''),
#   Text(1.08983,0.149267,''),
#   Text(1.08814,0.161126,''),
#   Text(1.08724,0.167048,''),
#   Text(1.08632,0.172965,''),
# ...
